-- %% [markdown]
-- # [CFDIReg]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [CFDIReg]    Script Date: 17/01/2025 03:40:30 p. m. ******/
CREATE DATABASE [CFDIReg]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'CFDIReg', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\CFDIReg.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'CFDIReg_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\CFDIReg_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [CFDIReg] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [CFDIReg].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [CFDIReg] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [CFDIReg] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [CFDIReg] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [CFDIReg] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [CFDIReg] SET ARITHABORT OFF 
GO
ALTER DATABASE [CFDIReg] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [CFDIReg] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [CFDIReg] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [CFDIReg] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [CFDIReg] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [CFDIReg] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [CFDIReg] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [CFDIReg] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [CFDIReg] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [CFDIReg] SET  DISABLE_BROKER 
GO
ALTER DATABASE [CFDIReg] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [CFDIReg] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [CFDIReg] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [CFDIReg] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [CFDIReg] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [CFDIReg] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [CFDIReg] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [CFDIReg] SET RECOVERY FULL 
GO
ALTER DATABASE [CFDIReg] SET  MULTI_USER 
GO
ALTER DATABASE [CFDIReg] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [CFDIReg] SET DB_CHAINING OFF 
GO
ALTER DATABASE [CFDIReg] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [CFDIReg] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [CFDIReg] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [CFDIReg] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'CFDIReg', N'ON'
GO
ALTER DATABASE [CFDIReg] SET QUERY_STORE = ON
GO
ALTER DATABASE [CFDIReg] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[CFDIs]

-- %%
USE [CFDIReg]
GO

-- %%
/****** Object:  Table [dbo].[CFDIs]    Script Date: 17/01/2025 03:40:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CFDIs](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RfcEmisor] [nvarchar](50) NULL,
	[RfcReceptor] [nvarchar](50) NULL,
	[FolioFiscal] [nvarchar](50) NULL,
	[FechaEmision] [datetime] NULL,
	[Total] [decimal](18, 2) NULL,
	[Estatus] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LogsValidacion]

-- %%
/****** Object:  Table [dbo].[LogsValidacion]    Script Date: 17/01/2025 03:40:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LogsValidacion](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RfcEmisor] [nvarchar](50) NULL,
	[RfcReceptor] [nvarchar](50) NULL,
	[FolioFiscal] [nvarchar](50) NULL,
	[Fecha] [datetime] NULL,
	[Estatus] [nvarchar](50) NULL,
	[ErrorMessage] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InsertarLogValidacion]

-- %%
/****** Object:  StoredProcedure [dbo].[InsertarLogValidacion]    Script Date: 17/01/2025 03:40:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[InsertarLogValidacion]
    @RfcEmisor NVARCHAR(50),
    @RfcReceptor NVARCHAR(50),
    @FolioFiscal NVARCHAR(50),
    @Estatus NVARCHAR(50),
    @ErrorMessage NVARCHAR(255) = NULL
AS
BEGIN
    INSERT INTO LogsValidacion (RfcEmisor, RfcReceptor, FolioFiscal, Fecha, Estatus, ErrorMessage)
    VALUES (@RfcEmisor, @RfcReceptor, @FolioFiscal, GETDATE(), @Estatus, @ErrorMessage);
END;
GO

-- %% [markdown]
-- # [CFDIReg]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [CFDIReg] SET  READ_WRITE 
GO
